# %%
# !pip install tweepy
# !pip install vaderSentiment

# %%
import pandas as pd 
import tweepy
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
#My Twitter API Authentication Variables
consumer_key = 'VAOAmjiy9wr6o3ALnN0j6sWQy'
consumer_secret = 'Ulpxy7zsP9XXv2gSTkJH8ldhnfh0Op9ZuL3nnGyv3CfVlHLKzW'
access_token = '1155637993031364610-DQmij8i8UbjuM3xMsl9TlrY5cI9kyo'
access_token_secret = 'LG4SSyeb7hUS9OVKJ91NOVraG1hCJodR6ocrMZyANBvo7'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth)
tweets = api.search('google', count=200)
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

#print(tweets[0].text)
display(data.head(10))
# Out:
#                                               Tweets
# 0  #pocketnews #currentaffairs #dailynews #shortn...
# 1  ★3　攻撃型　ベアトリス\n\n☆DLはこちら☆\n【iOS】\nhttps://t.co/...
# 2  Quand un employé de Google se moque de la Sili...
# 3  RT @audelorriaux: Invités par les fondateurs d...
# 4  RT @ExploramaGames: Suite à notre expérimentat...
# 5  RT @gfdonghyun: HELP RT\nMALAYSIA NON PROFIT G...
# 6  RT @Eva_Patinho: O 8 do 8 ás 8, de fai xusto 1...
# 7  RT @baekphoria: [DL] 190506 #Baekhyun #백현 2019...
# 8  RT @cjwerleman: Indian cricket legend MS Dhoni...
# 9  📌 Google Flight hará predicciones sobre retras...

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\micro\AppData\Roaming\nltk_data...
# True

# %%
sid = SentimentIntensityAnalyzer()
l=[]
for idx,row in data.iterrows():
    ss = sid.polarity_scores(row['Tweets'])
    l.append(ss)
    
se = pd.Series(l)
data['polarity'] = se.values

display(data.head(100))
#print(data.polarity[0]['compound'])
# Out:
#                                                Tweets  \
# 0   #pocketnews #currentaffairs #dailynews #shortn...
# 1   ★3　攻撃型　ベアトリス\n\n☆DLはこちら☆\n【iOS】\nhttps://t.co/...
# 2   Quand un employé de Google se moque de la Sili...
# 3   RT @audelorriaux: Invités par les fondateurs d...
# 4   RT @ExploramaGames: Suite à notre expérimentat...
# 5   RT @gfdonghyun: HELP RT\nMALAYSIA NON PROFIT G...
# 6   RT @Eva_Patinho: O 8 do 8 ás 8, de fai xusto 1...
# 7   RT @baekphoria: [DL] 190506 #Baekhyun #백현 2019...
# 8   RT @cjwerleman: Indian cricket legend MS Dhoni...
# 9   📌 Google Flight hará predicciones sobre retras...
# 10  RT @peachypinkshop: PLS RT (สุ่มแจก 1 อัลบั้ม)...
# 11  RT @ZardEXD: 190809.NTV.Oha!4 NEWS LIVE.BTS\nh...
# 12  RT @Otto_English: A quick Google search shows ...
# 13  RT @gyeolali: 🐥PO SLOGAN X1🐥\n\n✊IDR 75.000\n✊...
# 14  青春恋愛アプリ『地味なカレと私の事情』\n【Android】https://t.co/h9U...
# 15  @RioNa_ao3F あ、そっか(  ;ᯅ;   )\nりおなちゃん見てたかもやけど、公式...
# ...
